# %%
import pandas as pd

# %%
def Levenshtein_Distance(str1, str2):
    """
    计算字符串 str1 和 str2 的编辑距离
    :param str1
    :param str2
    :return:
    """
    matrix = [[ i + j for j in range(len(str2) + 1)] for i in range(len(str1) + 1)]
 
    for i in range(1, len(str1)+1):
        for j in range(1, len(str2)+1):
            if(str1[i-1] == str2[j-1]):
                d = 0
            else:
                d = 1
            
            matrix[i][j] = min(matrix[i-1][j]+1, matrix[i][j-1]+1, matrix[i-1][j-1]+d)
 
    return matrix[len(str1)][len(str2)]

def create_gene_mapper(path):
    hs2mma = {}
    for n, line in enumerate(open(path)):
        if n == 0:
            continue
        s = line.strip().split("\t")
        if s[1].startswith("ENSMMUG"):
            continue
        elif s[0] not in hs2mma:
            hs2mma[s[0]] = s[1]
        elif s[1] == hs2mma[s[0]]:
            continue
        else:
            d1 = Levenshtein_Distance(s[0].upper(), hs2mma[s[0]].upper(), )
            d2 = Levenshtein_Distance(s[0].upper(), s[1].upper())
            if d2 < d1:
                hs2mma[s[0]] = s[1]
    return hs2mma

# %%
hs2mma = create_gene_mapper("./gprofiler2/human2macaque.tsv")
mm2mma = create_gene_mapper("./gprofiler2/mouse2macaque.tsv")

# %%
lr_database = {}

for n, line in enumerate( open("./gprofiler2/cellchatdb_human.tsv") ):
    if n == 0:
        s = line.strip().split("\t")
        continue
    
    s = line.strip().split("\t")
    interaction_id, use_name, pathway_name, annot = s[0], s[-1], s[1], s[-2]

    l, r = use_name.strip().split(" - ")
    l = l.strip()
    r = r.strip().strip("()").split("+")
    l_mma = hs2mma.get(l, None)
    r_mma = [hs2mma[i] for i in r if i in hs2mma]
    if l_mma == None or len(r_mma) == 0:
        continue
    else:
        key = f"{l_mma} - ({'+'.join(r_mma)})"
        if not key in lr_database:
            lr_database[key] = [pathway_name, annot]

print(len(lr_database))

for n, line in enumerate( open("./gprofiler2/cellchatdb_mouse.tsv") ):
    if n == 0:
        s = line.strip().split("\t")
        continue
    
    s = line.strip().split("\t")
    interaction_id, use_name, pathway_name, annot = s[0], s[-1], s[1], s[-2]

    l, r = use_name.strip().split(" - ")
    l = l.strip()
    r = r.strip().strip("()").split("+")
    
    l_mma = mm2mma.get(l, None)
    r_mma = [mm2mma[i] for i in r if i in mm2mma]
    if l_mma == None or len(r_mma) == 0:
        print(l, r, l_mma, r_mma)
        continue
    else:
        key = f"{l_mma} - ({'+'.join(r_mma)})"
        if not key in lr_database:
            lr_database[key] = [pathway_name, annot]
        #print(key)

print(len(lr_database))
# Out:
# 1635
# Bmp8a ['Acvr1', 'Acvr2a'] None ['ACVR1', 'ACVR2A']
# Bmp8a ['Acvr1', 'Acvr2b'] None ['ACVR1', 'ACVR2B']
# Bmp8a ['Acvr1', 'Bmpr2'] None ['ACVR1', 'BMPR2']
# Bmp8a ['Bmpr1a', 'Acvr2a'] None ['BMPR1A', 'ACVR2A']
# Bmp8a ['Bmpr1a', 'Acvr2b'] None ['BMPR1A', 'ACVR2B']
# Bmp8a ['Bmpr1a', 'Bmpr2'] None ['BMPR1A', 'BMPR2']
# Bmp8a ['Bmpr1b', 'Acvr2a'] None ['BMPR1B', 'ACVR2A']
# Bmp8a ['Bmpr1b', 'Acvr2b'] None ['BMPR1B', 'ACVR2B']
# Bmp8a ['Bmpr1b', 'Bmpr2'] None ['BMPR1B', 'BMPR2']
# Bmp8b ['Acvr1', 'Acvr2a'] None ['ACVR1', 'ACVR2A']
# Bmp8b ['Acvr1', 'Acvr2b'] None ['ACVR1', 'ACVR2B']
# Bmp8b ['Acvr1', 'Bmpr2'] None ['ACVR1', 'BMPR2']
# Bmp8b ['Bmpr1a', 'Acvr2a'] None ['BMPR1A', 'ACVR2A']
# Bmp8b ['Bmpr1a', 'Acvr2b'] None ['BMPR1A', 'ACVR2B']
# Bmp8b ['Bmpr1a', 'Bmpr2'] None ['BMPR1A', 'BMPR2']
# Bmp8b ['Bmpr1b', 'Acvr2a'] None ['BMPR1B', 'ACVR2A']
# Bmp8b ['Bmpr1b', 'Acvr2b'] None ['BMPR1B', 'ACVR2B']
# Bmp8b ['Bmpr1b', 'Bmpr2'] None ['BMPR1B', 'BMPR2']
# Inhbc ['Acvr1b', 'Acvr2a'] None ['ACVR1B', 'ACVR2A']
# Inhbc ['Acvr1b', 'Acvr2b'] None ['ACVR1B', 'ACVR2B']
# Inhbc ['Acvr1c', 'Acvr2a'] None ['ACVR1C', 'ACVR2A']
# Inhbc ['Acvr1c', 'Acvr2b'] None ['ACVR1C', 'ACVR2B']
# Inhbabb ['Acvr1b', 'Acvr2a'] None ['ACVR1B', 'ACVR2A']
# Inhbabb ['Acvr1b', 'Acvr2b'] None ['ACVR1B', 'ACVR2B']
# Inhbabb ['Acvr1c', 'Acvr2a'] None ['ACVR1C', 'ACVR2A']
# Inhb ['Acvr1c', 'Acvr2b'] None ['ACVR1C', 'ACVR2B']
# Inhaba ['Acvr2a'] None ['ACVR2A']
# Inhabb ['Acvr2b'] None ['ACVR2B']
# Wnt5a ['Fzd1'] WNT5A []
# Wnt5b ['Fzd1'] WNT5B []
# Wnt11 ['Fzd1'] WNT11 []
# Fgf17 ['Fgfr1'] None ['FGFR1']
# Fgf17 ['Fgfr2'] None ['FGFR2']
# Fgf17 ['Fgfr3'] None ['FGFR3']
# Fgf17 ['Fgfr4'] None ['ZNF346']
# Vegfa ['Vegfr1'] VEGFA []
# Vegfa ['Vegfr2'] VEGFA []
# Vegfb ['Vegfr1'] VEGFB []
# Vegfc ['Vegfr3'] VEGFC []
# Vegfc ['Vegfr2'] VEGFC []
# Vegfd ['Vegfr3'] VEGFD []
# Vegfd ['Vegfr2'] VEGFD []
# Pgf ['Vegfr1'] PGF []
# Vegfa ['Vegfr1r2'] VEGFA []
# Vegfc ['Vegfr2r3'] VEGFC []
# Vegfd ['Vegfr2r3'] VEGFD []
# Igfl3 ['Igflr1'] None ['IGFLR1']
# Ins1 ['Inssr'] INS []
# Ins2 ['Inssr'] INS []
# Apln ['Aplnr'] None ['APLNR']
# Dhh ['Ptch2'] DHH []
# Ihh ['Ptch2'] IHH []
# Shh ['Ptch2'] SHH []
# Ccl24 ['Ccr3'] None ['CCR3']
# Ccl26 ['Ccr3'] None ['CCR3']
# Ccl1 ['Ccr8'] None ['CCR8']
# Ccl25 ['Ccr9'] None ['CCR9']
# Ccl25 ['Ackr4'] None ['ACKR4']
# Ccl1 ['Ackr4'] None ['ACKR4']
# Ccl1 ['Ackr1'] None ['ACKR1']
# Ccl24 ['Ackr2'] None ['ACKR2']
# Ccl26 ['Ackr2'] None ['ACKR2']
# Cxcl4 ['Cxcr3'] None ['CXCR3']
# Cxcl11 ['Cxcr3'] None ['CXCR3']
# Pf4 ['Cxcr3'] None ['CXCR3']
# Cxcl11 ['Ackr1'] None ['ACKR1']
# Cxcl11 ['Ackr3'] None ['ACKR3']
# Mif ['Cd74', 'Cxcr4'] None ['CD74', 'CXCR4']
# Mif ['Cd74', 'Cd44'] None ['CD74', 'CD44']
# Mif ['Cd74', 'Cxcr2'] None ['CD74', 'CXCR2']
# Mif ['Ackr3'] None ['ACKR3']
# Tslp ['Il7r', 'Crlf2'] None ['IL7R']
# Il4 ['Il4r'] IL4 []
# Ebi3 ['Il27ra', 'Il6st'] None ['IL27RA', 'IL6ST']
# Cntf ['Cntfr', 'Lifr'] None ['CNTFR', 'LIFR']
# Clcf1 ['Cntfr', 'Lifr'] None ['CNTFR', 'LIFR']
# Il1f5 ['Il1rl2', 'Il1rap'] None ['IL1RL2', 'IL1RAP']
# Il1f6 ['Il1rl2', 'Il1rap'] None ['IL1RL2', 'IL1RAP']
# Il1f8 ['Il1rl2', 'Il1rap'] None ['IL1RL2', 'IL1RAP']
# Il1f9 ['Il1rl2', 'Il1rap'] None ['IL1RL2', 'IL1RAP']
# Il17af ['Il17ra', 'Il17rc'] None ['IL17RA', 'IL17RC']
# Gh1 ['Ghr'] None ['GHR']
# Ifna ['Ifnar1', 'Ifnar2'] None ['IFNAR1', 'IFNAR2']
# Ifne ['Ifnar1', 'Ifnar2'] None ['IFNAR1', 'IFNAR2']
# Ifnl2 ['Ifnlr1', 'Il10rb'] None ['IFNLR1']
# Ifnl3 ['Ifnlr1', 'Il10rb'] None ['IFNLR1']
# Fasl ['Fas'] FASLG []
# Tnfsf12 ['Tnfrsf12a'] TNFSF12 []
# Cd70 ['Cd27'] CD70 []
# Tnfsf13 ['Tnfrsf17'] None ['TNFRSF17']
# Tnfsf13 ['Tnfrsf13b'] None []
# Tnfsf13b ['Tnfrsf13b'] TNFSF13B []
# Retn ['Tlr4'] None ['TLR4']
# Retn ['Cap1'] None ['CAP1']
# Kng1 ['Bdkrb1'] KNG1 []
# Kng2 ['Bdkrb1'] KNG1 []
# C4a ['C3ar1'] None ['C3AR1']
# C4b ['Cr2'] None ['CR2']
# Galp ['Galr1'] None ['GALR1']
# Galp ['Galr2'] None ['GALR2']
# Pomc ['Mc2r'] POMC []
# Npff ['Npffr1'] None ['NPFFR1']
# Npff ['Npffr2'] None ['NPFFR2']
# Npy ['Npy4r'] NPY []
# Npy ['Npy6r'] NPY []
# Npy ['Gpr83'] NPY []
# Npy ['Pgr15l'] NPY []
# Ppy ['Npy4r'] PPY []
# Ppy ['Npy6r'] PPY []
# Ppy ['Gpr83'] PPY []
# Ppy ['Pgr15l'] PPY []
# Pyy ['Npy4r'] PYY []
# Pyy ['Npy6r'] PYY []
# Pyy ['Gpr83'] PYY []
# Pyy ['Pgr15l'] PYY []
# Pdyn ['Oprd1'] PDYN []
# Penk ['Oprd1'] PENK []
# Pomc ['Oprd1'] POMC []
# Cort ['Sstr1'] None ['SSTR1']
# Cort ['Sstr2'] None ['SSTR2']
# Cort ['Sstr3'] None ['SSTR3']
# Cort ['Sstr4'] None ['SSTR4']
# Cort ['Sstr5'] None ['SSTR5']
# Tac4 ['Tacr1'] None ['TACR1']
# Uts2 ['Uts2r'] UTS2 []
# Prok1 ['Prokr1'] PROK1 []
# Prok2 ['Prokr1'] PROK2 []
# Ngfa ['Ntrk1'] None ['NTRK1']
# Apela ['Aplnr'] None ['APLNR']
# Enho ['Gpr19'] None ['GPR19']
# Insl3 ['Rxfp4'] INSL3 []
# Insl3 ['Rxfp3'] INSL3 []
# Insl5 ['Rxfp4'] INSL5 []
# Insl5 ['Rxfp3'] INSL5 []
# Lgals9 ['Cd45'] LGALS13 []
# Rln1 ['Rxfp3'] RLN2 []
# Rln1 ['Rxfp4'] RLN2 []
# Rln3 ['Rxfp3'] RLN3 []
# Rln3 ['Rxfp4'] RLN3 []
# Saa2 ['Fpr2'] None ['FPR2']
# Slurp1 ['Chrna4'] SLURP1 []
# Slurp2 ['Chrnb1'] None ['CHRNB1']
# Slurp2 ['Chrnb2'] None ['CHRNB2']
# Slurp2 ['Chrnb3'] None ['CHRNB3']
# Slurp2 ['Chrnb4'] None ['CHRNB4']
# Slurp2 ['Chrna1'] None ['CHRNA1']
# Slurp2 ['Chrna2'] None ['CHRNA2']
# Slurp2 ['Chrna3'] None ['CHRNA3']
# Slurp2 ['Chrna4'] None []
# Slurp2 ['Chrna5'] None ['CHRNA5']
# Slurp2 ['Chrna6'] None ['CHRNA6']
# Slurp2 ['Chrna7'] None ['CHRNA7']
# Slurp2 ['Chrna9'] None ['CHRNA9']
# Slurp2 ['Chrna10'] None ['CHRNA10']
# Slurp2 ['Chrnd'] None ['CHRND']
# Slurp2 ['Chrne'] None ['CHRNE']
# Slurp2 ['Chrng'] None ['CHRNG']
# Trh ['Trhr2'] TRH []
# Uts2b ['Uts2r'] UTS2B []
# Bag6 ['Ncr3-ps'] BAG6 []
# Col6a4 ['Itga1', 'Itgb1'] None ['ITGA1', 'ITGB1']
# Col9a3 ['Itga1', 'Itgb1'] None ['ITGA1', 'ITGB1']
# Col6a4 ['Itga2', 'Itgb1'] None ['ITGA2', 'ITGB1']
# Col9a3 ['Itga2', 'Itgb1'] None ['ITGA2', 'ITGB1']
# Lama1 ['Itga1', 'Itgb1'] None ['ITGA1', 'ITGB1']
# Lama5 ['Itga1', 'Itgb1'] None ['ITGA1', 'ITGB1']
# Lama1 ['Itga2', 'Itgb1'] None ['ITGA2', 'ITGB1']
# Lama5 ['Itga2', 'Itgb1'] None ['ITGA2', 'ITGB1']
# Lama1 ['Itga3', 'Itgb1'] None ['ITGA3', 'ITGB1']
# Lama5 ['Itga3', 'Itgb1'] None ['ITGA3', 'ITGB1']
# Col6a4 ['Itga3', 'Itgb1'] None ['ITGA3', 'ITGB1']
# Col9a3 ['Itga3', 'Itgb1'] None ['ITGA3', 'ITGB1']
# Lama1 ['Itga6', 'Itgb1'] None ['ITGA6', 'ITGB1']
# Lama5 ['Itga6', 'Itgb1'] None ['ITGA6', 'ITGB1']
# Lama1 ['Itga7', 'Itgb1'] None ['ITGA7', 'ITGB1']
# Lama5 ['Itga7', 'Itgb1'] None ['ITGA7', 'ITGB1']
# Npnt1 ['Itga8', 'Itgb1'] None ['ITGA8', 'ITGB1']
# Npnt2 ['Itga8', 'Itgb1'] None ['ITGA8', 'ITGB1']
# Col6a4 ['Itga9', 'Itgb1'] None ['ITGA9', 'ITGB1']
# Col9a3 ['Itga9', 'Itgb1'] None ['ITGA9', 'ITGB1']
# Lama1 ['Itga9', 'Itgb1'] None ['ITGA9', 'ITGB1']
# Lama5 ['Itga9', 'Itgb1'] None ['ITGA9', 'ITGB1']
# Col6a4 ['Itga10', 'Itgb1'] None ['ITGA10', 'ITGB1']
# Col9a3 ['Itga10', 'Itgb1'] None ['ITGA10', 'ITGB1']
# Col6a4 ['Itga11', 'Itgb1'] None ['ITGA11', 'ITGB1']
# Col9a3 ['Itga11', 'Itgb1'] None ['ITGA11', 'ITGB1']
# Dspp ['Itgav', 'Itgb1'] None ['ITGAV', 'ITGB1']
# Dspp ['Itgav', 'Itgb6'] None ['ITGAV', 'ITGB6']
# Lama1 ['Itgav', 'Itgb8'] None ['ITGAV', 'ITGB8']
# Lama5 ['Itgav', 'Itgb8'] None ['ITGAV', 'ITGB8']
# Col6a4 ['Itgav', 'Itgb8'] None ['ITGAV', 'ITGB8']
# Col9a3 ['Itgav', 'Itgb8'] None ['ITGAV', 'ITGB8']
# Lama1 ['Itga6', 'Itgb4'] None ['ITGA6', 'ITGB4']
# Lama5 ['Itga6', 'Itgb4'] None ['ITGA6', 'ITGB4']
# Col6a4 ['Cd44'] None ['CD44']
# Col9a3 ['Cd44'] None ['CD44']
# Lama1 ['Cd44'] None ['CD44']
# Lama5 ['Cd44'] None ['CD44']
# Col6a4 ['Sdc1'] None ['SDC1']
# Col9a3 ['Sdc1'] None ['SDC1']
# Col6a4 ['Sdc4'] None ['SDC4']
# Col9a3 ['Sdc4'] None ['SDC4']
# Lama1 ['Sv2a'] None ['SV2A']
# Lama5 ['Sv2a'] None ['SV2A']
# Lama1 ['Sv2b'] None ['SV2B']
# Lama5 ['Sv2b'] None ['SV2B']
# Lama1 ['Sv2c'] None ['SV2C']
# Lama5 ['Sv2c'] None ['SV2C']
# Vwf ['Gp complex'] VWF []
# Col6a4 ['Gp6'] None ['GP6']
# Col9a3 ['Gp6'] None ['GP6']
# Lama1 ['Dag1'] None ['DAG1']
# Lama5 ['Dag1'] None ['DAG1']
# Entpd1 ['Adora2a'] ENTPD1 []
# Cd99 ['Pilra'] None []
# Cd99 ['Cd99'] None []
# Cd209a ['Ceacam1'] CD209 []
# Ceacam1 ['Ceacam5'] None ['CEACAM5']
# Sele ['Ceacam1'] SELE []
# Clec2f ['Klrb1f'] None ['KLRB1']
# Efna4 ['Epha1'] None ['EPHA1']
# Efna4 ['Epha2'] None ['EPHA2']
# Efna4 ['Epha3'] None ['EPHA3']
# Efna4 ['Epha4'] None ['EPHA4']
# Efna4 ['Epha5'] None ['EPHA5']
# Efna4 ['Epha7'] None ['EPHA7']
# Efna4 ['Epha8'] None ['EPHA8']
# Gp1ba ['Itgam', 'Itgb2'] None ['ITGAM', 'ITGB2']
# Icam5 ['Cd209f'] ICAM5 []
# Jam1 ['Itgal', 'Itgb2'] None ['ITGAL', 'ITGB2']
# Mag ['Mag'] None []
# H2-t23 ['Klrd1', 'Klrc1'] None ['KLRD1']
# H2-t23 ['Klrd1', 'Klrc2'] None ['KLRD1']
# H2-m2 ['Cd8a'] None ['CD8A']
# H2-m3 ['Cd8a'] None ['CD8A']
# H2-m9 ['Cd8a'] None ['CD8A']
# H2-q1 ['Cd8a'] None ['CD8A']
# H2-q10 ['Cd8a'] None ['CD8A']
# H2-q2 ['Cd8a'] None ['CD8A']
# H2-q7 ['Cd8a'] None ['CD8A']
# H2-q8 ['Cd8a'] None ['CD8A']
# H2-t22 ['Cd8a'] None ['CD8A']
# H2-t23 ['Cd8a'] None ['CD8A']
# H2-t24 ['Cd8a'] None ['CD8A']
# H2-t3 ['Cd8a'] None ['CD8A']
# H2-t9 ['Cd8a'] None ['CD8A']
# H2-m10.4 ['Cd8a'] None ['CD8A']
# H2-m11 ['Cd8a'] None ['CD8A']
# H2-m1 ['Cd8a'] None ['CD8A']
# H2-m10.5 ['Cd8a'] None ['CD8A']
# H2-m10.2 ['Cd8a'] None ['CD8A']
# H2-m10.6 ['Cd8a'] None ['CD8A']
# H2-t10 ['Cd8a'] None ['CD8A']
# H2-q6 ['Cd8a'] None ['CD8A']
# H2-m10.3 ['Cd8a'] None ['CD8A']
# H2-bl ['Cd8a'] None ['CD8A']
# H2-d1 ['Cd8a'] None ['CD8A']
# H2-k1 ['Cd8a'] None ['CD8A']
# H2-m10.1 ['Cd8a'] None ['CD8A']
# H2-t18 ['Cd8a'] None ['CD8A']
# H2-q9 ['Cd8a'] None ['CD8A']
# Gm8909 ['Cd8a'] None ['CD8A']
# H2-l ['Cd8a'] None ['CD8A']
# Gm10499 ['Cd8a'] None ['CD8A']
# H2-q4 ['Cd8a'] None ['CD8A']
# H2-t-ps ['Cd8a'] None ['CD8A']
# Gm11127 ['Cd8a'] None ['CD8A']
# H2-m5 ['Cd8a'] None ['CD8A']
# Gm7030 ['Cd8a'] None ['CD8A']
# H2-m2 ['Cd8b1'] None []
# H2-m3 ['Cd8b1'] None []
# H2-m9 ['Cd8b1'] None []
# H2-q1 ['Cd8b1'] None []
# H2-q10 ['Cd8b1'] None []
# H2-q2 ['Cd8b1'] None []
# H2-q7 ['Cd8b1'] None []
# H2-q8 ['Cd8b1'] None []
# H2-t22 ['Cd8b1'] None []
# H2-t23 ['Cd8b1'] None []
# H2-t24 ['Cd8b1'] None []
# H2-t3 ['Cd8b1'] None []
# H2-t9 ['Cd8b1'] None []
# H2-m10.4 ['Cd8b1'] None []
# H2-m11 ['Cd8b1'] None []
# H2-m1 ['Cd8b1'] None []
# H2-m10.5 ['Cd8b1'] None []
# H2-m10.2 ['Cd8b1'] None []
# H2-m10.6 ['Cd8b1'] None []
# H2-t10 ['Cd8b1'] None []
# H2-q6 ['Cd8b1'] None []
# H2-m10.3 ['Cd8b1'] None []
# H2-bl ['Cd8b1'] None []
# H2-d1 ['Cd8b1'] None []
# H2-k1 ['Cd8b1'] None []
# H2-m10.1 ['Cd8b1'] None []
# H2-t18 ['Cd8b1'] None []
# H2-q9 ['Cd8b1'] None []
# Gm8909 ['Cd8b1'] None []
# H2-l ['Cd8b1'] None []
# Gm10499 ['Cd8b1'] None []
# H2-q4 ['Cd8b1'] None []
# H2-t-ps ['Cd8b1'] None []
# Gm11127 ['Cd8b1'] None []
# H2-m5 ['Cd8b1'] None []
# Gm7030 ['Cd8b1'] None []
# H2-bi ['Kir3dl1'] None ['KIR3DL12']
# H2-d1 ['Kir3dl1'] None ['KIR3DL12']
# H2-k1 ['Kir3dl1'] None ['KIR3DL12']
# H2-q1 ['Kir3dl1'] None ['KIR3DL12']
# H2-q10 ['Kir3dl1'] None ['KIR3DL12']
# H2-q2 ['Kir3dl1'] None ['KIR3DL12']
# H2-q4 ['Kir3dl1'] None ['KIR3DL12']
# H2-q6 ['Kir3dl1'] None ['KIR3DL12']
# H2-q7 ['Kir3dl1'] None ['KIR3DL12']
# H2-d ['Klra'] None []
# H2-k1 ['Klra'] None []
# Ulbp1 ['Klrk1'] None ['NKG2D']
# H60a ['Klrk1'] None ['NKG2D']
# H2-ea-ps ['Cd4'] None ['CD4']
# H2-aa ['Cd4'] None ['CD4']
# H2-ab1 ['Cd4'] None ['CD4']
# H2-eb1 ['Cd4'] None ['CD4']
# H2-dma ['Cd4'] None ['CD4']
# H2-dmb1 ['Cd4'] None ['CD4']
# H2-dmb2 ['Cd4'] None ['CD4']
# H2-oa ['Cd4'] None ['CD4']
# H2-ob ['Cd4'] None ['CD4']
# Ulbp1 ['Klrk1', 'Hcst'] None ['NKG2D', 'HCST']
# Dlk1 ['Notch4'] DLK1 []
# Dll1 ['Notch4'] DLL1 []
# Dll3 ['Notch4'] DLL3 []
# Dll4 ['Notch4'] DLL4 []
# Jag1 ['Notch4'] JAG1 []
# Jag2 ['Notch4'] JAG2 []
# Sell ['Glycam1'] SELL []
# Sema4a ['Plxnb3'] SEMA4A []
# Sema4d ['Plxnb3'] SEMA4D []
# Sema4a ['Timd2'] SEMA4A []
# Sema5a ['Plxnb3'] SEMA5A []
# 1696

# %%
pd.DataFrame(lr_database).T.sort_values(by=[1]).to_csv("macaque_lr_database.tsv", sep="\t", header=None)

# %%
! less -S macaque_lr_database.tsv |awk -F '[\t]' '{print $3}' |sort |uniq -c |sort -k1,1nr
# Out:
#    1062 Secreted Signaling
#     379 ECM-Receptor
#     255 Cell-Cell Contact

# %%
! less -S macaque_lr_database.tsv |awk -F '[\t]' '{print $2}' |sort |uniq -c |sort -k1,1nr
# Out:
#     320 WNT
#     176 COLLAGEN
#     117 LAMININ
#      62 CCL
#      58 BMP
#      56 FGF
#      39 SEMA3
#      31 CXCL
#      30 THBS
#      29 EPHA
#      29 PARs
#      28 ncWNT
#      28 TENASCIN
#      24 NOTCH
#      18 EGF
#      16 EPHB
#      15 ANGPTL
#      15 SLURP
#      13 FN1
#      13 NRG
#      12 IL4
#      12 JAM
#      12 NODAL
#      12 TGFb
#      11 RLN
#      11 SEMA4
#      10 ACTIVIN
#      10 IFN-I
#      10 NECTIN
#       9 IL2
#       9 MK
#       9 NPY
#       9 NRXN
#       9 OPIOID
#       9 SPP1
#       8 CALCR
#       8 ICAM
#       8 IGF
#       8 IL1
#       8 IL10
#       8 PTN
#       7 NT
#       7 SEMA6
#       6 DESMOSOME
#       6 EDN
#       6 GDF
#       6 PDGF
#       6 UCN
#       6 VTN
#       5 CLEC
#       5 CNTN
#       5 COMPLEMENT
#       5 GDNF
#       5 IL17
#       5 NCAM
#       5 PTH
#       5 SOMATOSTATIN
#       4 BMP10
#       4 CD23
#       4 CD40
#       4 CDH
#       4 GHRH
#       4 IL6
#       4 LT
#       4 MELANOCORTIN
#       4 MHC-I
#       4 MHC-II
#       4 MSTN
#       4 NMU
#       4 PROK
#       4 SEMA5
#       3 ANGPT
#       3 AVP
#       3 CD39
#       3 CD80
#       3 CD99
#       3 CDH1
#       3 GALANIN
#       3 GALECTIN
#       3 GAS
#       3 GCG
#       3 HH
#       3 ICOS
#       3 ITGB2
#       3 L1CAM
#       3 MPZ
#       3 NGF
#       3 NGL
#       3 SELL
#       3 SELPLG
#       3 TAC
#       3 THY1
#       3 VCAM
#       2 ADIPONECTIN
#       2 AGT
#       2 AMH
#       2 ANNEXIN
#       2 BAFF
#       2 BSP
#       2 CADM
#       2 CCK
#       2 CD226
#       2 CD45
#       2 CD86
#       2 CD96
#       2 CEACAM
#       2 CHEMERIN
#       2 CRH
#       2 CSF
#       2 EDA
#       2 FSH
#       2 GH
#       2 GIPR
#       2 GPR
#       2 GUCA
#       2 HCRT
#       2 IL12
#       2 LHB
#       2 LIFR
#       2 LIGHT
#       2 NPR1
#       2 NPVF
#       2 NPW-B
#       2 NTS
#       2 OSM
#       2 PERIOSTIN
#       2 PMCH
#       2 PROS
#       2 PSAP
#       2 PVR
#       2 RANKL
#       2 SELE
#       2 SEMA7
#       2 TIGIT
#       2 TNF
#       2 TRAIL
#       2 TSH
#       2 UROTENSIN
#       2 VIP
#       2 VISFATIN
#       2 VWF
#       1 ADGRE5
#       1 AGRN
#       1 ALCAM
#       1 APJ
#       1 APP
#       1 BRADYKININ
#       1 BST2
#       1 BTLA
#       1 CD137
#       1 CD1D2
#       1 CD200
#       1 CD22
#       1 CD30
#       1 CD34
#       1 CD46
#       1 CD48
#       1 CD52
#       1 CD6
#       1 CDH5
#       1 CHAD
#       1 CLDN
#       1 CSF3
#       1 CSPG4
#       1 CX3C
#       1 DMP1
#       1 EPGN
#       1 EPO
#       1 ESAM
#       1 FLT3
#       1 GHRELIN
#       1 GITRL
#       1 GNRH
#       1 GRN
#       1 HGF
#       1 HSPG
#       1 IFN-II
#       1 IL16
#       1 KISS1
#       1 KIT
#       1 LAIR1
#       1 LCK
#       1 LEP
#       1 MADCAM
#       1 NEGR
#       1 NPR2
#       1 NPS
#       1 OCLN
#       1 OSTN
#       1 OX40
#       1 OXT
#       1 PACAP
#       1 PD-L1
#       1 PDL2
#       1 PECAM1
#       1 PRL
#       1 PRLH
#       1 PTPRM
#       1 QRFP
#       1 RELN
#       1 SCT
#       1 SN
#       1 THPO
#       1 TRH
#       1 TWEAK
#       1 UGRP1
#       1 UTS2
#       1 VEGI
#       1 VISTA
#       1 XCR
